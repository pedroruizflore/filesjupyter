# %% [markdown]
# # Project Ideas
# # 10/10/2025

# %%
"""
File: Maia_ProjectIdeas_10-10-2025.ipynb
Author: Pedro Maia
Date: 10/10/25
Last Modified: 10/10/2025
Description: Project Ideas
"""

# %%
Data analysis:

First Idea -> Have the average user ratings of video games changed over time?

The average user rating of video games has been on a slow, slight decline over the past 10-15 years, 
possibly due to increased competition and saturation in the market. A dataset of video games that includes 
the Release Year and a User Score.

Use pandas to load and clean the dataset, focusing only on the Release Year and Rating; 
Group the data by Release Year and use NumPy functions to calculate the average rating for games released in that year; 
Create a Line Plot showing the trend of the average rating over the years.

Second Idea -> Is there a correlation between the day of the year and the daily temperature range?

I will investigate the correlation between daily cloud cover and the daily temperature range across all seasons. 
My expanded hypothesis is that increased average cloud cover on a given day is correlated with a 
smaller daily temperature range (clouds act as an insulator, keeping nights warmer and days cooler).

Data Source: Publicly available historical daily weather data for a single city. The dataset must now include: 
Date, High Temp, Low Temp, and a measure of Cloud Cover or Precipitation.

Use pandas to calculate a new column for the Temperature Range (High and Low).
Group the data by Month to find the average range for each month.
Create a simple Line Plot showing the average temperature range for each month of the year.



Program 1:

Type: Standalone Program 
Concept: A program that not only generates a random maze on a grid but then uses a simple algorithm 
to automatically find and display the solution path.

Grid Representation: Use a NumPy 2D array to represent the maze grid. Each cell is an integer (0 for a path, 1 for a wall).

Maze Generation: Implement a basic algorithm to randomly carve paths through the grid.

Visualization: Use a library like Pygame to visually draw the maze.

Solver Algorithm: Implement a simple pathfinding algorithm that takes the start and end points of the NumPy array and returns the sequence of coordinates for the solution.

Output: Display the maze, then draw the calculated solution path over the maze. Pandas is not strictly needed here but NumPy is essential for grid manipulation and linear algebra (if you wanted to get fancy with movement vectors).


Program 2: 

Type: Game-Style (Continuous Input/Text-Based)
Concept: A simplified, text-based Role-Playing Game (RPG) focusing solely on inventory and resource management—think 
a basic merchant or dungeon explorer. The user interacts by typing commands (buy sword, check inventory, use potion).

Inventory System: Use a Python dictionary or list of dictionaries to represent the inventory. This is your core data structure.

Resource Management Loop: A continuous loop that displays the player's current gold and inventory, then prompts for a command.

Shops: Use a basic CSV file read by pandas to store all available items (Name, Cost, Weight, Effect). The program reads this data at startup.

NumPy Application: Use NumPy arrays to manage a simple, fixed set of character attributes (Health, Stamina, Damage Bonus) which are modified by items in the inventory.
