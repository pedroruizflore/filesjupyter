# %% [markdown]
# # In Class
# # 09/17/2025

# %%
Slide 4: Introduction
. A **list** allows the programmer tomanipulate a sequence of data values of any types
. A dictionary organizes data values by association with other data values rather than by sequential position
# Out:
#   Cell In[1], line 1
#     Slide 4: Introduction
#           ^
# SyntaxError: invalid syntax

# %%
Slide 5
. List: Sequence of data values (items or elements)
. Some examples:
 - Shopping list for the grocery store
 - To-do list
 - Roster for an athletic team
 - Guest list for a wedding
 - Recipe, which is a list of instructions
 - Text document, which is a list of lines
 - Names in a phone book
# Out:
#   Cell In[2], line 1
#     Slide 5
#           ^
# SyntaxError: invalid syntax

# %%
Slide 6: List Literals and Basic Operators
. Some examples:

# %%
fruit = ["apples", "oranges", "cherries"]
num = [[5,9],[541,78]]

# %%
print(f'my number list is {num}, and my fruit is {fruit}')
# Out:
# my number list is [[5, 9], [541, 78]], and my fruit is ['apples', 'oranges', 'cherries']

# %%
import math 
x = 2

# %%
[2, math.sqrt(x)]
# Out:
# [2, 1.4142135623730951]

# %%
first = [1,2,3,4]
second = list(range(1,5))

# %%
first
# Out:
# [1, 2, 3, 4]

# %%
second
# Out:
# [1, 2, 3, 4]

# %%
third = list("Hi there!")

# %%
third
# Out:
# ['H', 'i', ' ', 't', 'h', 'e', 'r', 'e', '!']

# %%
fourth = list("123456")

# %%
fourth
# Out:
# ['1', '2', '3', '4', '5', '6']

# %%
len(first)
# Out:
# 4

# %%
first[0]
# Out:
# 1

# %%
third[2:7]
# Out:
# [' ', 't', 'h', 'e', 'r']

# %%
"z" in third
# Out:
# False

# %%
"p" in third
# Out:
# False

# %%
Slide 10: Replacing an Element in a List
. A list is mutable
 - Elements can be inserted, removed or replaced

# %%
num2 = [1,2,3,4,5,6,7]
num2
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
num2[3] = 0
num2
# Out:
# [1, 2, 3, 0, 5, 6, 7]

# %%
num3 = [2,3,4,5,6]
for index in range(len(num3)):
    num3[index] = num3[index]**2
num3
# Out:
# [4, 9, 16, 25, 36]

# %%
sentence = "This example has five words."
words = sentence.split()
words
# Out:
# ['This', 'example', 'has', 'five', 'words.']

# %%
for index in range(len(words)):
    words[index] = words[index].upper()
words
# Out:
# ['THIS', 'EXAMPLE', 'HAS', 'FIVE', 'WORDS.']

# %%
num3.insert(9,1000)
num3
# Out:
# [4, 100, 9, 16, 25, 36, 1000]

# %%
num3.extend(['no', 'way'])
num3
# Out:
# [4, 100, 9, 16, 25, 36, 1000, 'no', 'way']

# %%
Slide 16: Searching a List
. **in **determines an element's presence or absence, but does not return position of element (if found)

# %%
aList = [34,45,67]
target = int(input("What number do you want to look for? "))
if target in aList:
    print(f'Your number is located in teh{aList.index(target)} index position')
else:
    print("It is not there")
# Out:
# What number do you want to look for?  45
# Your number is located in teh1 index position

# %%
Slide 17: Sorting a List
. A list's elements are always ordered by position, but you can impose a natural ordering on them
 - For example, in alphabetical order
. When the elements can be related by comparing them <,> and ==, they can be sorted
 - The method sort mutates a list by arranging its elements is ascending order

# %%
num = [4,2,10,8]
num
# Out:
# [4, 2, 10, 8]

# %%
num.sort ()
num
# Out:
# [2, 4, 8, 10]

# %% [markdown]
# # l

# %%
. All of the functions and methods examined in previous chapters return a value that the caller can then use to complete its work
. Mutator methods (e.g., insert, append, extend, pop, and sort) usually return no value of interest to caller
 - Python automatically returns the special value None

# %%
aList = aList.sort()
print(aList)
# Out:
# None

# %%
first = [10,20,30]
second = first
print(first, "and", second)
# Out:
# [10, 20, 30] and [10, 20, 30]

# %%
first[1] = 99
print(first, "and", second)
# Out:
# [10, 99, 30] and [10, 99, 30]

# %%
third = []
for element in first:
    third.append(element)
first[0] = 1000
print(first, "and", third)
# Out:
# [1000, 99, 30] and [10, 99, 30]

# %%
fourth = first.copy()
fourth
# Out:
# [1000, 99, 30]

# %%
. Programmers might need to see whether two variables refer to the exact same object or to different objects
. Example, you might want to determine whether one variable is an alias for another
. The == operator returns True if the variables are aliases for the same object
. Unfortunately, == also returns True if the contents of two different objects are the same
. The first relation is called object identity

# %%
third = list(first)
print(first == second, first == third, first is third)
# Out:
# True True False

# %%
"""
file: median.py
Author: someone else, wasn't me 
Purpose\description:
Prints the median of a set of numbers in a file
"""

fileName = input("enter the fileName: ")
f = open(fileName, 'r')
numbers = []
for line in f:
    words = line.split()
    for word in words:
        numbers.append(float(word))

numbers.sort()
midpoint = len(numbers) // 2
print("The median is", end = " ")
if len(numbers) % 2 == 1:
      print(numbers[midpoint])
else:
    print((numbers[midpoint] + numbers[midpoint - 1]) / 2)
# Out:
# enter the fileName:  Untitled1.ipynb
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 14
#      12     words = line.split()
#      13     for word in words:
# ---> 14         numbers.append(float(word))
#      16 numbers.sort()
#      17 midpoint = len(numbers) // 2
#
# ValueError: could not convert string to float: '{'
